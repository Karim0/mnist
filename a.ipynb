# %%
from matplotlib import pyplot as plt
from scipy import special
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
mnist_test = pd.read_csv("data/mnist_test.csv", header=None)
mnist_train = pd.read_csv("data/mnist_train.csv", header=None)

# %%
X_train, y_train = mnist_train.drop(columns=0), mnist_train[0]
X_test, y_test = mnist_test.drop(columns=0), mnist_test[0]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-3-f7749cd16566> in <module>
# ----> 1 X_train, y_train = mnist_train.drop(columns=0), mnist_train[0]
#       2 X_test, y_test = mnist_test.drop(columns=0), mnist_test[0]
#
# c:\users\karim\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# c:\users\karim\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
l = np.array([i for i in mnist_test.iloc[0, 1:]])
l.shape = (28, 28)
plt.imshow(l)

# %%
print('[')
for i in range(3, 4):
    
    
    for j in np.array(mnist_test[mnist_test[0] == i].iloc[0, 1:]):
        print(j, '%2C', sep='', end='')
    print('%5D\"', end=',\n')
print(']')

# %%
print('[')
for i in range(10):
    
    print('\"http://192.168.1.8:8000/num_with_page/?pixs=%5B', end='')
    for j in np.array(mnist_test[mnist_test[0] == i].iloc[0, 1:]):
        print(j, '%2C', sep='', end='')
    print('%5D\"', end=',\n')
print(']')

# %%
fig, axs = plt.subplots(nrows=2, ncols=5, figsize=(20, 10))
p = 0
for i in range(2):
    for j in range(5):
        l = np.array(mnist_test[mnist_test[0] == p].iloc[0, 1:])
        l.shape = (28, 28)
        axs[i][j].imshow(l, cmap='gray_r', interpolation='nearest')
        p+=1
